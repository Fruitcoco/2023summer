# %% [markdown]
# ## Cramer-Rao lower bound (CRLB)

# %% [markdown]
# This gives a lower bound on the possible variance for an **unbiased estimator**

# %% [markdown]
# ![CramerRaolowerbound.png](attachment:CramerRaolowerbound.png)
